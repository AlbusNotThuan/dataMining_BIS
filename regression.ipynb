# %%
import pandas as pd

# %%
dim_product = pd.read_csv('data/DimProduct.csv', delimiter=';')
dim_vendor = pd.read_csv('data/DimVendor.csv', delimiter=';')
dim_purchase_order = pd.read_csv('data/DimPurchaseOrder.csv', delimiter=';')
dim_shipper = pd.read_csv('data/DimShip.csv', delimiter=';')

list_dim = [dim_product, dim_vendor, dim_purchase_order, dim_shipper]

# %%
dim_product.drop(columns=['Name', 'Size'])
# Out:
#      ProductID                   Name ProductNumber  MakeFlag  StandardCost  \
# 0            1        Adjustable Race       AR-5381     False        0.0000
# 1            2           Bearing Ball       BA-8327     False        0.0000
# 2            3        BB Ball Bearing       BE-2349      True        0.0000
# 3            4  Headset Ball Bearings       BE-2908     False        0.0000
# 4          316                  Blade       BL-2036      True        0.0000
# ..         ...                    ...           ...       ...           ...
# 499        995      ML Bottom Bracket       BB-8107      True       44.9506
# 500        996      HL Bottom Bracket       BB-9108      True       53.9416
# 501        997     Road-750 Black, 44    BK-R19B-44      True      343.6496
# 502        998     Road-750 Black, 48    BK-R19B-48      True      343.6496
# 503        999     Road-750 Black, 52    BK-R19B-52      True      343.6496
#
#      ListPrice Size  ProductSubcategoryID
# ...

# %%
for dim in list_dim:
    dim.dropna(inplace=True)
    print(dim.shape)
# Out:
# (211, 8)
# (209, 1)
# (8845, 7)
# (5, 4)
# (1, 4)
